# %% [markdown]
# Jose Salvador Negrete Serrato

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
import math 
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(0.00155,0.00158,0.000001)
y=0.0872*np.sqrt(x**4 - 1.9975*x**2 + 1) / np.cos(x*1000 - np.arctan(0.05*x / 1 - x**2))
plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.show()

# %% [markdown]
# Como puede verse, existe entonces una resonancia, es decir, donde la amplitud alcanza un valor muy diferente comparado con el de otros puntos.

# %% [markdown]
# ![2.png](attachment:2.png)

# %%
import math 
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(0,1,0.001)
y=x*1000-(0.0872*np.sqrt(x**4 - 1.9975*x**2 + 1))
plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.show()

# %% [markdown]
# ![3.png](attachment:3.png)

# %%
import math 
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(1000,1010,0.001)
y=np.cos(x-np.arctan(1)) / np.sqrt(32)
plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.show()

# %%
import math 
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(1000,1010,0.001)
y=-np.sin(x-np.arctan(1)) / np.sqrt(32)
plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.show()

# %%
import math 
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(1000,1010,0.001)
y=2*np.cos(2*x-np.arctan(1)) / np.sqrt(128)
plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.show()

# %%
import math 
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(1000,1010,0.001)
y=-4*np.sin(2*x-np.arctan(1)) / np.sqrt(128)
plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.show()

# %% [markdown]
# ![4.png](attachment:4.png)

# %%
import math 
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(1000,1010,0.001)
y1=np.cos(x-np.arctan(1)) / np.sqrt(32)
y2=-np.sin(x-np.arctan(1)) / np.sqrt(32)
y3=2*np.cos(2*x-np.arctan(1)) / np.sqrt(128)
y4=-4*np.sin(2*x-np.arctan(1)) / np.sqrt(128)

plt.figure(figsize=(10,10))
plt.plot(y1,y2)
plt.plot(y3,y4)
plt.show()

# %% [markdown]
# ![5.png](attachment:5.png)

# %%
import math 
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(1000,1010,0.001)
y1=10*np.cos(4*x) / 15
y2=-40*np.sin(4*x) / 15
y3=np.cos(4*x)
y4=-4*np.sin(4*x)

plt.figure(figsize=(10,10))
plt.plot(y1,y2)
plt.plot(y3,y4)
plt.show()

# %% [markdown]
# ![6.png](attachment:6.png)

# %%
import math 
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(1000,1010,0.001)
y1=np.cos(2*x) / 3
y2=-2*np.sin(2*x) / 3
y3=np.cos(2*x-np.arctan(-4/3)) / 5
y4=-2*np.sin(2*x-np.arctan(-4/3)) / 5
y5=np.cos(2*x-np.arctan(-0.2/3)) / np.sqrt(9.04)
y6=-2*np.sin(2*x-np.arctan(-0.2/3)) / np.sqrt(9.04)

plt.figure(figsize=(10,10))
plt.plot(y1,y2)
plt.plot(y3,y4)
plt.plot(y5,y6)
plt.show()

# %% [markdown]
# ![7.png](attachment:7.png)

# %%
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np

def pend(y, t, a):
    theta, omega = y
    dydt = [omega, -a*np.sin(theta)]
    return dydt
a = 1
y0 = [0.6024, 0.0]
t = np.linspace(0, 40, 100)
plt.figure(figsize=(10,10))
sol = odeint(pend, y0, t, args=(a,))
plt.plot(t, sol[:, 0], 'b', label='Ecuacion no lineal')
plt.plot(t, 0.6024*np.cos(t), 'r', label='Ecuacion lineal')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %%
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np

def pend(y, t, a):
    theta, omega = y
    dydt = [omega, -a*np.sin(theta)]
    return dydt
a = 1
y0 = [0.6024, 0.0]
t = np.linspace(0, 40, 100)
sol = odeint(pend, y0, t, args=(a,))
plt.figure(figsize=(10,10))
plt.plot(t, sol[:, 1], 'b', label='Ecuacion no lineal')
plt.plot(t, -0.6024*np.sin(t), 'r', label='Ecuacion lineal')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %% [markdown]
# ![8.png](attachment:8.png)

# %%
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np

def pend(y, t, a):
    theta, omega = y
    dydt = [omega, -a*np.sin(theta)]
    return dydt

t = np.linspace(0, 40, 100)
a = 1
y0 = [-1.5707, 0.0]
sol0 = odeint(pend, y0, t, args=(a,))
y1 = [-1.3962, 0.0]
sol1 = odeint(pend, y1, t, args=(a,))
y2 = [-1.2217, 0.0]
sol2 = odeint(pend, y2, t, args=(a,))
y3 = [-1.0471, 0.0]
sol3 = odeint(pend, y3, t, args=(a,))
y4 = [-0.8726, 0.0]
sol4 = odeint(pend, y4, t, args=(a,))
y5 = [-0.6981, 0.0]
sol5 = odeint(pend, y5, t, args=(a,))
y6 = [-0.5235, 0.0]
sol6 = odeint(pend, y6, t, args=(a,))
y7 = [-0.3490, 0.0]
sol7 = odeint(pend, y7, t, args=(a,))
y8 = [-0.1745, 0.0]
sol8 = odeint(pend, y8, t, args=(a,))
y9 = [0.0, 0.0]
sol9 = odeint(pend, y9, t, args=(a,))
y10 = [0.1745, 0.0]
sol10 = odeint(pend, y10, t, args=(a,))
y11 = [0.3490, 0.0]
sol11 = odeint(pend, y11, t, args=(a,))
y12 = [0.5235, 0.0]
sol12 = odeint(pend, y12, t, args=(a,))
y13 = [0.6981, 0.0]
sol13 = odeint(pend, y13, t, args=(a,))
y14 = [0.8726, 0.0]
sol14 = odeint(pend, y14, t, args=(a,))
y15 = [1.0471, 0.0]
sol15 = odeint(pend, y15, t, args=(a,))
y16 = [1.2217, 0.0]
sol16 = odeint(pend, y16, t, args=(a,))
y17 = [1.3962, 0.0]
sol17 = odeint(pend, y17, t, args=(a,))
y18 = [1.5707, 0.0]
sol18 = odeint(pend, y18, t, args=(a,))

plt.figure(figsize=(10,10))
plt.plot(sol0[:, 0], sol0[:, 1], 'b')
plt.plot(sol1[:, 0], sol1[:, 1], 'r')
plt.plot(sol2[:, 0], sol2[:, 1], 'y')
plt.plot(sol3[:, 0], sol3[:, 1], 'g')
plt.plot(sol4[:, 0], sol4[:, 1], 'b')
plt.plot(sol5[:, 0], sol5[:, 1], 'r')
plt.plot(sol6[:, 0], sol6[:, 1], 'y')
plt.plot(sol7[:, 0], sol7[:, 1], 'g')
plt.plot(sol8[:, 0], sol8[:, 1], 'b')
plt.plot(sol9[:, 0], sol9[:, 1], 'r')
plt.plot(sol10[:, 0], sol10[:, 1], 'y')
plt.plot(sol11[:, 0], sol11[:, 1], 'g')
plt.plot(sol12[:, 0], sol12[:, 1], 'b')
plt.plot(sol13[:, 0], sol13[:, 1], 'r')
plt.plot(sol14[:, 0], sol14[:, 1], 'y')
plt.plot(sol15[:, 0], sol15[:, 1], 'g')
plt.plot(sol16[:, 0], sol16[:, 1], 'b')
plt.plot(sol17[:, 0], sol17[:, 1], 'r')
plt.plot(sol18[:, 0], sol18[:, 1], 'y')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %%
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np

def pend(y, t, a):
    theta, omega = y
    dydt = [omega, -a*np.sin(theta)]
    return dydt

t = np.linspace(0, 40, 100)
a = 1
y0 = [-1.5707, 0.0]
sol0 = odeint(pend, y0, t, args=(a,))
y1 = [1.5707, 0.0]
sol1 = odeint(pend, y1, t, args=(a,))
plt.figure(figsize=(10,10))
plt.plot(sol0[:, 0] + sol1[:, 0], sol0[:, 1] + sol1[:, 1], 'b')

# %% [markdown]
# El código usado para el ejercicio 2 está incluenciado por el ejemplo llevado a cabo en la solución de una ecuación diferencial similar que se encuentra en la página https://docs.scipy.org/doc/scipy-0.18.1/reference/generated/scipy.integrate.odeint.html
